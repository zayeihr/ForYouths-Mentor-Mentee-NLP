# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the Dataset

# %%
def load_data(file_path):
    # Load data from the Excel file
    mentee_info = pd.read_excel(file_path, sheet_name='Mentee Info')
    mentor_info = pd.read_excel(file_path, sheet_name='Mentor Info')
    
    # Fill NaN values in text fields with empty strings
    mentee_info.fillna('', inplace=True)
    mentor_info.fillna(''
                       , inplace=True)
    return mentee_info, mentor_info

# %%
# Define the path to the Excel file
file_path = 'Mentor-Mentee Matching Data.xlsx'

# Load and preprocess the data
mentee_info, mentor_info = load_data(file_path)

# %%
print(" Print the Mentee Information\n")
mentee_info.head()
# Out:
#  Print the Mentee Information
#                 Timestamp  \
# 0 2023-01-21 23:35:35.853
# 1 2023-03-06 22:18:27.101
# 2 2023-03-07 08:42:51.290
# 3 2023-03-13 12:45:54.397
# 4 2023-03-13 14:30:35.331
#
#   I acknowledge that I have read and understood the above PDPA Notice and consent to the collection, use and disclosure of my personal data by The Academic Label for the purposes set out in the Notice.  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Full Name Age Email Address Phone Number  \
# 0
# 1
# 2
# 3
# 4
#
#   How often would you like to be contacted for mentoring sessions? (eg. Weekdays, Weekends, morning, afternoon, night, weekly, fortnightly etc.)  \
# 0                                   Weekends morning
# 1    Weekdays nights, weekly to monthly all possible
# 2                                           Anything
# 3                                           Weekends
# 4                                     Weekend, night
#
#   What is your preferred platform(s) to communicate with your mentor? (Phone call, Telegram, WhatsApp, Meet Up etc.)  \
# 0               Video call on any platform/meet ups
# 1                                Telegram / WhatsApp
# 2                                           Whatsapp
# 3                                           Telegram
# 4                                 Whatsapp, telegram
#
#   Which school are you currently attending?  \
# 0                      Temasek Polytechnic
# 1                                       NJC
# 2                       Riverside secondary
# 3               Nanyang Girls' High School
# 4                                      Nyjc
#
#   Which year of school are you currently in? (eg. Sec 4, J1, poly year 1, ITE year 1)  \
# 0                                          Graduated
# 1                                                 J2
# 2                                              Sec 4
# 3                                              Sec 4
# 4                                                 J2
#
#      What course/subject combination are you taking?  \
# 0                            Biomedical Engineering
# 1                                   PCME + H3 Econs
# 2  Expresss (phy Chem) combined elect hist/ss POA...
# 3  Triple Science (Bio, Chem, Advanced Physics, I...
# 4                                               Pcme
#
#   I have an idea of what course I want to pursue.  \
# 0                                             Yes
# 1                                             Yes
# 2                                             Yes
# 3                                             Yes
# 4                                             Yes
#
#                             5 (Most interested)  \
# 0                                 Allied Health
# 1               UK (Economics/Finance/Politics)
# 2                          Information security
# 3  UK (Medicine/Dentistry/Veterinarian Science)
# 4                                  Data science
#
#                                                    4                    3  \
# 0
# 1                                            Finance           Accounting
# 2                                   Computer Science  Mass communications
# 3  Australia (Medicine/Dentistry/Veterinarian Sci...             Sciences
# 4                                        Mathematics              Finance
#
#                                  2 1 (least interested)  \
# 0
# 1                        Economics             Business
# 2              Mass communications           Accounting
# 3  UK (Economics/Finance/Politics)           Psychology
# 4                        Economics          Engineering
#
#   If you have selected the (others) option, do specify what course you are interested in, and the number associated with it [example: Food Science in Netherlands (5)]  \
# 0
# 1
# 2                                                Nil
# 3  Veterinary Medicine/Veterinary Science in New ...
# 4
#
#     What do you hope to achieve out of this program?  \
# 0  Idk, a clearer understanding in my choice of c...
# 1  I hope to be able to find out more specific kn...
# 2  Better results or a better view of tertiary ed...
# 3  I hope to gain advice and opportunities to hel...
# 4           Gain more knowledge of the course I want
#
#                                  Profile Description
# 0  I am currently exploring a career in allied he...
# 1  My interests lie in economics, finance, accoun...
# 2  I am at a crossroads in choosing my tertiary e...
# 3  My ambition is to study Veterinary Medicine, a...
# 4  I am passionate about data science, mathematic...

# %%
print(" Print the Mentor Information\n")
mentor_info.head()
# Out:
#  Print the Mentor Information
#                 Timestamp  \
# 0 2022-11-18 20:15:35.526
# 1 2022-11-18 22:36:26.148
# 2 2022-11-18 22:53:50.506
# 3 2022-11-18 23:05:20.230
# 4 2022-11-19 09:58:28.383
#
#   I acknowledge that I have read and understood the above PDPA Notice and consent to the collection, use and disclosure of my personal data by The Academic Label for the purposes set out in the Notice.  \
# 0
# 1
# 2
# 3
# 4
#
#   Full Name How much time can you commit to the mentorship program?  \
# 0                                           once every 2 weeks
# 1                                           once every 2 weeks
# 2                                           once every 2 weeks
# 3                                                  once a week
# 4                                           once every 2 weeks
#
#   What is/are your preferred platform(s) to communicate with your mentee? (Phone call, Telegram, WhatsApp, Meet Up etc.)  \
# 0                                          Zoom Call
# 1         Tele, whatsapp, zoom, meetups for dec only
# 2                                           Telegram
# 3                            Telegram, Discord, Zoom
# 4                                           Telegram
#
#   Which school are you currently attending?  \
# 0                 Graduated NTU in Dec 2022
# 1                                       NTU
# 2                                       NTU
# 3                                       SMU
# 4                                       SMU
#
#   What academic course are you currently enrolled in?  \
# 0                  Renaissance Engineering Programme
# 1          Double degree in accounting and business
# 2                                     PhD in Physics
# 3                                Information Systems
# 4        Politics, Law, and Economics + Data Science
#
#   Which year of school are you currently in? (eg. year 1, 2)  \
# 0                                         Fresh Grad
# 1                                                  1
# 2                                             year 1
# 3                                             Year 2
# 4                                                  4
#
#   Briefly explain the academic courses and/or subject fields that you would be able to provide advice on.  \
# 0  Data Analytics, Business Analytics, Mechanical...
# 1          Consulting (mainly)/High finance/auditing
# 2  Physics, engineering, and computer science rel...
# 3  Information Systems, Computer Science, Softwar...
# 4  Courses: Anything economics or gov/policy rela...
#
#                                  Profile Description
# 0  Hi, I specialize in Data Analytics, Business A...
# 1  Hello! My main areas of expertise are Consulti...
# 2  Hi there! I have a strong background in Physic...
# 3  Hey! I specialize in Information Systems, Comp...
# 4  Hi! I can provide guidance on courses related ...

# %% [markdown]
# # Preprocess of Mentor and Mentee Information

# %%
def preprocess_data(mentee_info, mentor_info):
    # Combine relevant text fields for mentees and mentors
    mentee_texts = mentee_info['Profile Description'] + " " + mentee_info['What course/subject combination are you taking?']
    mentor_texts = mentor_info['Profile Description'] + " " + mentor_info['Briefly explain the academic courses and/or subject fields that you would be able to provide advice on.']
    return mentee_texts, mentor_texts

# %%
mentee_texts, mentor_texts = preprocess_data(mentee_info, mentor_info)

# %%
print(" Print the Mentee Information after processing\n")
mentee_texts
# Out:
#  Print the Mentee Information after processing
# 0     I am currently exploring a career in allied he...
# 1     My interests lie in economics, finance, accoun...
# 2     I am at a crossroads in choosing my tertiary e...
# 3     My ambition is to study Veterinary Medicine, a...
# 4     I am passionate about data science, mathematic...
# 5     I am interested in social sciences, psychology...
# 6     My primary goal is to pursue a career in medic...
# 7     I am exploring career options in accounting, f...
# 8     I am currently exploring my interests in allie...
# 9     I am passionate about business, economics, law...
# 10    I am particularly interested in pursuing a deg...
# 11    I seek guidance to help me achieve my future c...
# 12    I hope to gain clarity about the courses I wan...
# 13    I am exploring various career paths, including...
# 14    I am interested in marketing, visual arts, law...
# 15    I am exploring my interests in history, media ...
# 16    I am interested in pursuing a career in occupa...
# 17    I am currently exploring various fields, inclu...
# 18    Through this mentorship, I aim to understand t...
# 19    I am considering careers in dentistry, law, ac...
# 20    I am exploring diverse fields such as allied h...
# 21    I am interested in computer science, mathemati...
# 22    I am exploring various fields, including engin...
# 23    I hope to gain guidance on what to expect from...
# 24    I am interested in sciences, medicine, dentist...
# 25    I have diverse interests in liberal arts, soci...
# 26    I am exploring careers in medicine, pharmaceut...
# 27    I am interested in medicine, psychology, denti...
# dtype: object

# %%
print(" Print the Mentor Information after processing\n")
mentor_texts
# Out:
#  Print the Mentor Information after processing
# 0     Hi, I specialize in Data Analytics, Business A...
# 1     Hello! My main areas of expertise are Consulti...
# 2     Hi there! I have a strong background in Physic...
# 3     Hey! I specialize in Information Systems, Comp...
# 4     Hi! I can provide guidance on courses related ...
# 5     Hi! I can share insights on JC Biology and off...
# 6     Hello! I have a strong foundation in Medicine,...
# 7     Hi! I'm passionate about Global Studies, Inter...
# 8     Hey! My expertise lies in Mechanical Engineeri...
# 9     Hello! I'm adept at providing guidance on gene...
# 10    Hi! I specialize in Consulting, Strategy, Busi...
# 11    Hello! With a strong foundation in Medicine, B...
# 12    Hi there! My area of expertise is Economics, a...
# 13    Hello! As someone deeply involved in the field...
# 14    Hi! I hold a Business Diploma from NP and have...
# dtype: object

# %% [markdown]
# # Feature Extraction

# %%
def calculate_similarity(mentee_texts, mentor_texts):
    # Feature Engineering using TF-IDF
    tfidf_vectorizer = TfidfVectorizer()
    mentee_tfidf = tfidf_vectorizer.fit_transform(mentee_texts)
    mentor_tfidf = tfidf_vectorizer.transform(mentor_texts)
    
    # Calculate cosine similarity between all mentees and mentors
    return cosine_similarity(mentee_tfidf, mentor_tfidf)

# %%
# Calculate similarity and get top matches
similarity_matrix = calculate_similarity(mentee_texts, mentor_texts)

# %%
similarity_matrix
# Out:
# array([[0.17230387, 0.12095088, 0.16090645, 0.19524347, 0.13125372,
#        [0.25120493, 0.20289009, 0.29545918, 0.25727759, 0.21791291,
#         0.21720084, 0.19457913, 0.24076272, 0.15117213, 0.15206464,
#         0.15324695, 0.23101009, 0.19351439, 0.26671473, 0.14697154],
#        [0.24684993, 0.20113782, 0.22950212, 0.18786138, 0.17263878,
#         0.16939776, 0.21117189, 0.24243489, 0.13879945, 0.15537531,
#         0.16944055, 0.25985995, 0.21521567, 0.20844339, 0.17005011]])

# %% [markdown]
# # Print the top matches for each mentee with Mentor

# %%
def get_top_n_matches(similarity_matrix, mentee_info, mentor_info, top_n=3):
    match_results = {}
    for mentee_idx, mentee_row in enumerate(similarity_matrix):
        top_indices = np.argsort(mentee_row)[::-1][:top_n]
        match_scores = mentee_row[top_indices]
        mentee_name = mentee_info.iloc[mentee_idx]['Full Name'] if mentee_info.iloc[mentee_idx]['Full Name'] else f'Mentee {mentee_idx+1}'
        match_results[mentee_name] = [
            (mentor_info.iloc[i]['Full Name'] if mentor_info.iloc[i]['Full Name'] else f'Mentor {i+1}', score) for i, score in zip(top_indices, match_scores)
        ]
    return match_results



top_matches = get_top_n_matches(similarity_matrix, mentee_info, mentor_info)

# Print the top matches for each mentee
for mentee, matches in top_matches.items():
    print(f"{mentee} is best matched with:")
    for mentor, score in matches:
        print(f"  {mentor} with a similarity score of {score:.2f}")
    print()
# Out:
# Mentee 1 is best matched with:
#   Mentor 4 with a similarity score of 0.20
#   Mentor 12 with a similarity score of 0.19
#   Mentor 13 with a similarity score of 0.19
#
# Mentee 2 is best matched with:
#   Mentor 5 with a similarity score of 0.34
#   Mentor 2 with a similarity score of 0.29
#   Mentor 13 with a similarity score of 0.28
#
# Mentee 3 is best matched with:
#   Mentor 4 with a similarity score of 0.28
#   Mentor 3 with a similarity score of 0.25
#   Mentor 2 with a similarity score of 0.24
#
# Mentee 4 is best matched with:
#   Mentor 3 with a similarity score of 0.23
#   Mentor 14 with a similarity score of 0.22
#   Mentor 1 with a similarity score of 0.20
#
# Mentee 5 is best matched with:
#   Mentor 8 with a similarity score of 0.34
#   Mentor 1 with a similarity score of 0.33
#   Mentor 3 with a similarity score of 0.32
#
# Mentee 6 is best matched with:
#   Mentor 12 with a similarity score of 0.29
#   Mentor 10 with a similarity score of 0.26
#   Mentor 7 with a similarity score of 0.25
#
# Mentee 7 is best matched with:
#   Mentor 12 with a similarity score of 0.31
#   Mentor 7 with a similarity score of 0.27
#   Mentor 14 with a similarity score of 0.26
#
# Mentee 8 is best matched with:
#   Mentor 1 with a similarity score of 0.28
#   Mentor 2 with a similarity score of 0.28
#   Mentor 5 with a similarity score of 0.27
#
# Mentee 9 is best matched with:
#   Mentor 8 with a similarity score of 0.25
#   Mentor 2 with a similarity score of 0.22
#   Mentor 1 with a similarity score of 0.22
#
# Mentee 10 is best matched with:
#   Mentor 2 with a similarity score of 0.38
#   Mentor 13 with a similarity score of 0.37
#   Mentor 11 with a similarity score of 0.35
#
# Mentee 11 is best matched with:
#   Mentor 9 with a similarity score of 0.41
#   Mentor 3 with a similarity score of 0.31
#   Mentor 8 with a similarity score of 0.29
#
# Mentee 12 is best matched with:
#   Mentor 2 with a similarity score of 0.47
#   Mentor 11 with a similarity score of 0.36
#   Mentor 12 with a similarity score of 0.34
#
# Mentee 13 is best matched with:
#   Mentor 3 with a similarity score of 0.26
#   Mentor 13 with a similarity score of 0.24
#   Mentor 1 with a similarity score of 0.24
#
# Mentee 14 is best matched with:
#   Mentor 11 with a similarity score of 0.27
#   Mentor 10 with a similarity score of 0.22
#   Mentor 13 with a similarity score of 0.20
#
# Mentee 15 is best matched with:
#   Mentor 2 with a similarity score of 0.28
#   Mentor 12 with a similarity score of 0.28
#   Mentor 13 with a similarity score of 0.26
#
# Mentee 16 is best matched with:
#   Mentor 3 with a similarity score of 0.25
#   Mentor 2 with a similarity score of 0.22
#   Mentor 9 with a similarity score of 0.20
#
# Mentee 17 is best matched with:
#   Mentor 8 with a similarity score of 0.26
#   Mentor 11 with a similarity score of 0.20
#   Mentor 2 with a similarity score of 0.20
#
# Mentee 18 is best matched with:
#   Mentor 1 with a similarity score of 0.29
#   Mentor 2 with a similarity score of 0.28
#   Mentor 11 with a similarity score of 0.28
#
# Mentee 19 is best matched with:
#   Mentor 3 with a similarity score of 0.27
#   Mentor 13 with a similarity score of 0.25
#   Mentor 2 with a similarity score of 0.24
#
# Mentee 20 is best matched with:
#   Mentor 3 with a similarity score of 0.28
#   Mentor 2 with a similarity score of 0.25
#   Mentor 11 with a similarity score of 0.21
#
# Mentee 21 is best matched with:
#   Mentor 8 with a similarity score of 0.22
#   Mentor 14 with a similarity score of 0.19
#   Mentor 1 with a similarity score of 0.19
#
# Mentee 22 is best matched with:
#   Mentor 2 with a similarity score of 0.31
#   Mentor 3 with a similarity score of 0.31
#   Mentor 10 with a similarity score of 0.28
#
# Mentee 23 is best matched with:
#   Mentor 3 with a similarity score of 0.27
#   Mentor 13 with a similarity score of 0.27
#   Mentor 1 with a similarity score of 0.24
#
# Mentee 24 is best matched with:
#   Mentor 10 with a similarity score of 0.38
#   Mentor 2 with a similarity score of 0.36
#   Mentor 3 with a similarity score of 0.32
#
# Mentee 25 is best matched with:
#   Mentor 6 with a similarity score of 0.29
#   Mentor 12 with a similarity score of 0.23
#   Mentor 8 with a similarity score of 0.22
#
# Mentee 26 is best matched with:
#   Mentor 3 with a similarity score of 0.23
#   Mentor 10 with a similarity score of 0.22
#   Mentor 15 with a similarity score of 0.21
#
# Mentee 27 is best matched with:
#   Mentor 3 with a similarity score of 0.30
#   Mentor 14 with a similarity score of 0.27
#   Mentor 4 with a similarity score of 0.26
#
# Mentee 28 is best matched with:
#   Mentor 12 with a similarity score of 0.26
#   Mentor 1 with a similarity score of 0.25
#   Mentor 8 with a similarity score of 0.24
